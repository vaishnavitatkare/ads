# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
RDM =pd.read_excel("/content/exp3_RelianceDataMart.xlsx")
RDM
# Out:
#     Rice_Bag_Weight
# 0             24.50
# 1             24.70
# 2             25.60
# 3             25.00
# 4             24.70
# 5             23.30
# 6             23.30
# 7             24.00
# 8             25.10
# 9             24.30
# 10            23.30
# 11            24.10
# 12            24.10
# 13            24.20
# 14            25.20
# 15            24.90
# 16            24.70
# 17            24.10
# 18            25.00
# 19            24.70
# 20            24.90
# 21            25.00
# 22            24.00
# 23            23.98
# 24            24.30
# 25            24.20
# 26            24.56
# 27            24.50
# 28            24.70

# %%
print(RDM.mean())
# Out:
# Rice_Bag_Weight    24.446207
# dtype: float64

# %%
RDM.describe()
# Out:
#        Rice_Bag_Weight
# count        29.000000
# mean         24.446207
# std           0.569463
# min          23.300000
# 25%          24.100000
# 50%          24.500000
# 75%          24.900000
# max          25.600000

# %%
one_sample_result=stats.ttest_1samp(RDM,24.446)

# %%
print(one_sample_result)
# Out:
# TtestResult(statistic=array([0.00195653]), pvalue=array([0.99845279]), df=array([28]))

# %% [markdown]
# For Pre Post Score dataset

# %%
pre_post_score=pd.read_excel("/content/Pre_Post_Score.xlsx")
pre_post_score
# Out:
#     Pre_Score     Post_Score      Diff  Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0        18.0             22 -4.000000         NaN         NaN        NaN
# 1        21.0             25 -4.000000         NaN         NaN        NaN
# 2        16.0             17 -1.000000         NaN         NaN        NaN
# 3        22.0             24 -2.000000         NaN         NaN        NaN
# 4        19.0             16  3.000000         NaN         NaN        NaN
# 5        24.0             29 -5.000000         NaN         NaN        NaN
# 6        17.0             20 -3.000000         NaN         NaN        NaN
# 7        21.0             23 -2.000000         NaN         NaN        NaN
# 8        23.0             19  4.000000         NaN         NaN        NaN
# 9        18.0             20 -2.000000         NaN         NaN        NaN
# 10       14.0             15 -1.000000         NaN         NaN        NaN
# 11       16.0             15  1.000000         NaN         NaN        NaN
# ...

# %%
two_sample_result=stats.ttest_rel(pre_post_score["Pre_Score"],pre_post_score["Post_Score"])
two_sample_result
# Out:
# TtestResult(statistic=nan, pvalue=nan, df=nan)
